# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.linear_model import LinearRegression
from statsmodels.formula.api import ols, glm
# %precision 3
np.random.seed(250514)

# %%
d=pd.read_excel('11장_단순회귀분석.xlsx',header=1)
df=d[['연도','광고비','매출액']]
df
# Out:
#       연도  광고비  매출액
# 0   2006   13   94
# 1   2007    8   70
# 2   2008   10   90
# 3   2009   15  100
# 4   2010   12   95
# 5   2011   15  100
# 6   2012   14   85
# 7   2013   15   95
# 8   2014   17  105
# 9   2015   19  105
# 10  2016   20  110
# 11  2017   21  105
# 12  2018   22  104
# 13  2019   21  105
# 14  2020   25  121

# %%
df[['광고비','연도']].corr()
# Out:
#           광고비        연도
# 광고비  1.000000  0.936223
# 연도   0.936223  1.000000

# %%
'''Rformula = 'quality ~ fixed_acidity + volatile_acidity + citric_acid + \
    residual_sugar + chlorides + free_sulfur_dioxide + total_sulfur_dioxide + \
    density + pH + sulphates + alcohol'''
form = '매출액 ~ 연도 + 광고비'
regression_result = ols(form, data = df).fit()
regression_result.summary()
# Out:
# d:\2Anaconda\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   res = hypotest_fun_out(*samples, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    매출액   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     28.50
# Date:                Wed, 14 May 2025   Prob (F-statistic):           2.77e-05
# Time:                        11:25:08   Log-Likelihood:                -44.676
# No. Observations:                  15   AIC:                             95.35
# Df Residuals:                      12   BIC:                             97.48
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
'''Rformula = 'quality ~ fixed_acidity + volatile_acidity + citric_acid + \
    residual_sugar + chlorides + free_sulfur_dioxide + total_sulfur_dioxide + \
    density + pH + sulphates + alcohol'''
form = '매출액 ~ 광고비'
regression_result = ols(form, data = df).fit()
regression_result.summary()
# Out:
# d:\2Anaconda\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   res = hypotest_fun_out(*samples, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    매출액   R-squared:                       0.788
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     48.44
# Date:                Wed, 14 May 2025   Prob (F-statistic):           9.92e-06
# Time:                        13:13:09   Log-Likelihood:                -46.146
# No. Observations:                  15   AIC:                             96.29
# Df Residuals:                      13   BIC:                             97.71
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
# intercept: 2976.4212, coef: -1.4578, 3.4597
# Adj R-squared: 0.797, 설명력 높은 편
# F 검정: h0: 회귀식 유의하지 않음, p<0.05, h0 can reject, 회귀식 유의하다 봄

# %%
reg=LinearRegression().fit(df[['광고비','연도']],df['매출액'])

# %%
# Out:
# d:\2Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 reg.predict([2021,2022])
#
# File d:\2Anaconda\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File d:\2Anaconda\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# ...

# %%
dof1=1
dof2=13

# %%
f_stats=0.5
stats.f(f_stats,dfd=13)

# %%
stats.f.ppf(0.95,dof1,dof2)
# Out:
# 4.667

# %%
help(stats.f.ppf)
# Out:
# Help on method ppf in module scipy.stats._distn_infrastructure:
#
# ppf(q, *args, **kwds) method of scipy.stats._continuous_distns.f_gen instance
#     Percent point function (inverse of `cdf`) at q of the given RV.
#
#     Parameters
#     ----------
#     q : array_like
#         lower tail probability
#     arg1, arg2, arg3,... : array_like
#         The shape parameter(s) for the distribution (see docstring of the
#         instance object for more information)
#     loc : array_like, optional
#         location parameter (default=0)
#     scale : array_like, optional
#         scale parameter (default=1)
#
#     Returns
#     -------
#     x : array_like
#         quantile corresponding to the lower tail probability q.
